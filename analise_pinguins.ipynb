# %% [markdown]
# # Indentificação de espécie de pinguins através das características com SVM e Random Forest
#
# penguins_size.csv: Simplified data from original penguin data sets. Contains variables:
#
# species: penguin species (Chinstrap, Adélie, or Gentoo)<br />
# culmen_length_mm: culmen length (mm) - Anatomia, comprimento<br />
# culmen_depth_mm: culmen depth (mm) - Anatomia, profundidade<br />
# flipper_length_mm: flipper length (mm) - comprimento nadadeira<br />
# body_mass_g: body mass (g)<br />
# island: island name (Dream, Torgersen, or Biscoe) in the Palmer Archipelago (Antarctica)<br />
# sex: penguin sex<br />

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import ipyplot
import seaborn as sns

from sklearn import preprocessing 
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %matplotlib inline

# %%
labels = ['Chinstrap','Adeliae','Gentoo']
img_list = ['https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Chinstrap_Penguin.jpg/375px-Chinstrap_Penguin.jpg',
            'https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Pygoscelis_adeliae.jpg/375px-Pygoscelis_adeliae.jpg',
            'https://upload.wikimedia.org/wikipedia/commons/0/0a/MADRE_PINGUINO_Y_CRIA.jpg']

ipyplot.plot_images(img_list, labels, img_width=200)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-EwyggN4y67pyrEiHvX2Z8u {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-EwyggN4y67pyrEiHvX2Z8u {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-EwyggN4y67pyrEiHvX2Z8u {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-EwyggN4y67pyrEiHvX2Z8u:checked ~ #ipyplot-html-viewer-textarea-EwyggN4y67pyrEiHvX2Z8u {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-EwyggN4y67pyrEiHvX2Z8u:checked + #ipyplot-html-viewer-label-EwyggN4y67pyrEiHvX2Z8u:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-EwyggN4y67pyrEiHvX2Z8u">
#         <label id="ipyplot-html-viewer-label-EwyggN4y67pyrEiHvX2Z8u" for="ipyplot-html-viewer-toggle-EwyggN4y67pyrEiHvX2Z8u">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-EwyggN4y67pyrEiHvX2Z8u" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-nfMpyXxrVvYaRe8kFzk3Ys {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-nfMpyXxrVvYaRe8kFzk3Ys {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-nfMpyXxrVvYaRe8kFzk3Ys">
#     <div class="ipyplot-placeholder-div-nfMpyXxrVvYaRe8kFzk3Ys">
#         <div id="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-RVd5yGi9VPYdYFbxNoRhFF" class="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Chinstrap</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Chinstrap_Penguin.jpg/375px-Chinstrap_Penguin.jpg</h4><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Chinstrap_Penguin.jpg/375px-Chinstrap_Penguin.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-RVd5yGi9VPYdYFbxNoRhFF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nfMpyXxrVvYaRe8kFzk3Ys">
#         <div id="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-NSovnxWLZ6NHYhWiGEGhyD" class="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Adeliae</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Pygoscelis_adeliae.jpg/375px-Pygoscelis_adeliae.jpg</h4><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Pygoscelis_adeliae.jpg/375px-Pygoscelis_adeliae.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-NSovnxWLZ6NHYhWiGEGhyD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nfMpyXxrVvYaRe8kFzk3Ys">
#         <div id="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-9rqFLFbBeUxxLEc6ALESn2" class="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Gentoo</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://upload.wikimedia.org/wikipedia/commons/0/0a/MADRE_PINGUINO_Y_CRIA.jpg</h4><img src="https://upload.wikimedia.org/wikipedia/commons/0/0a/MADRE_PINGUINO_Y_CRIA.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-9rqFLFbBeUxxLEc6ALESn2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-nfMpyXxrVvYaRe8kFzk3Ys {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-nfMpyXxrVvYaRe8kFzk3Ys {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-nfMpyXxrVvYaRe8kFzk3Ys">
#     <div class="ipyplot-placeholder-div-nfMpyXxrVvYaRe8kFzk3Ys">
#         <div id="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-RVd5yGi9VPYdYFbxNoRhFF" class="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Chinstrap</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Chinstrap_Penguin.jpg/375px-Chinstrap_Penguin.jpg</h4><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Chinstrap_Penguin.jpg/375px-Chinstrap_Penguin.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-RVd5yGi9VPYdYFbxNoRhFF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nfMpyXxrVvYaRe8kFzk3Ys">
#         <div id="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-NSovnxWLZ6NHYhWiGEGhyD" class="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Adeliae</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Pygoscelis_adeliae.jpg/375px-Pygoscelis_adeliae.jpg</h4><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/24/Pygoscelis_adeliae.jpg/375px-Pygoscelis_adeliae.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-NSovnxWLZ6NHYhWiGEGhyD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-nfMpyXxrVvYaRe8kFzk3Ys">
#         <div id="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-9rqFLFbBeUxxLEc6ALESn2" class="ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Gentoo</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">https://upload.wikimedia.org/wikipedia/commons/0/0a/MADRE_PINGUINO_Y_CRIA.jpg</h4><img src="https://upload.wikimedia.org/wikipedia/commons/0/0a/MADRE_PINGUINO_Y_CRIA.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-nfMpyXxrVvYaRe8kFzk3Ys-9rqFLFbBeUxxLEc6ALESn2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
df = pd.read_csv('datasets/penguins_size.csv')

df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df = df = df.dropna()

# %%
# Removendo categorias inválidas

display(pd.unique(df['sex']))
df = df.drop(df[df['sex'] == '.'].index)
display(pd.unique(df['sex']))
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)
# array(['MALE', 'FEMALE'], dtype=object)

# %%
# Analisando o balanceamento dos dados através da quantidade de amostras por sexo e espécie
sns.countplot(x='species', hue='sex', data=df)

# %%
# Analisando as espécies existentes em cada região
sns.countplot(x='island', hue='species', data=df)

# %%
# Analise da anatomia das amostras por sexo (peso x comprimento).  
sns.scatterplot(x='body_mass_g', y='culmen_length_mm', hue="sex", data=df)

# %%
# Analise do peso de cada espécie por sexo. A Raça Gentoo é a espécie com mais massa, os machos apresentam mais massa em todas as espécies.
sns.scatterplot(x='body_mass_g', y='species', hue="sex", data=df)

# %%
encoder = preprocessing.LabelEncoder()
df['species'] = encoder.fit_transform(df.species)
df['sex'] = encoder.fit_transform(df.sex)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    int64
#  1   island             333 non-null    object
#  2   culmen_length_mm   333 non-null    float64
#  3   culmen_depth_mm    333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 30.8+ KB

# %%
sns.pairplot(df, diag_kind="hist", hue="species")

# %%
X = df.drop(['island','species'], axis=1) 
y = df['species']

X.head()
# Out:
#    culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  sex
# 0              39.1             18.7              181.0       3750.0    1
# 1              39.5             17.4              186.0       3800.0    0
# 2              40.3             18.0              195.0       3250.0    0
# 4              36.7             19.3              193.0       3450.0    0
# 5              39.3             20.6              190.0       3650.0    1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

model = SVC()
model.fit(X_train,y_train)
predictions = model.predict(X_test)

score = accuracy_score(y_test, predictions)

print('Score = %.5f' % score)
# Out:
# Score = 0.66000

# %%
# O SVM não obteve boa acurácia e não se adaptou bem aos dados

print(classification_report(y_test, predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.95      0.70        40
#            1       0.00      0.00      0.00        27
#            2       0.90      0.85      0.88        33
#
#     accuracy                           0.66       100
#    macro avg       0.48      0.60      0.52       100
# weighted avg       0.52      0.66      0.57       100
#
# [[38  0  2]
#  [26  0  1]
#  [ 5  0 28]]

# %%
# Utilizando random forest 

model = RandomForestClassifier(n_estimators=10, n_jobs=-1)
model.fit(X_train,y_train)
predictions = model.predict(X_test)

score = accuracy_score(y_test, predictions)

print('Score = %.5f' % score)
# Out:
# Score = 0.94000

# %%
# Random forest apresentou ótimos resultados

print(classification_report(y_test, predictions))
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        40
#            1       0.96      0.81      0.88        27
#            2       1.00      0.97      0.98        33
#
#     accuracy                           0.94       100
#    macro avg       0.95      0.93      0.94       100
# weighted avg       0.94      0.94      0.94       100
#
# [[40  0  0]
#  [ 5 22  0]
#  [ 0  1 32]]
